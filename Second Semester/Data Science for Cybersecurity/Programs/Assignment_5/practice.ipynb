# %%
# implementing linear regression

# %%
# lets import sklearn things
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
# import dataset
import seaborn as sns

df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(df)  # basic eda

# %%
# lets do total bill and tip
sns.lmplot(df, x="tip", y="total_bill")

# %%
# lets implement linear regression and just see if its kinda the same
model = LinearRegression()

# %%
# split
xtr, xtst, ytr, ytst = train_test_split(
    df[["tip"]], df["total_bill"], train_size=0.8, random_state=42
)
xtr
# Out:
#       tip
# 228  2.72
# 208  2.03
# 96   4.00
# 167  4.50
# 84   2.03
# ..    ...
# 106  4.06
# 14   3.02
# 92   1.00
# 179  3.55
# 102  2.50
#
# [195 rows x 1 columns]

# %%
# fit the model
model.fit(xtr, ytr)
# Out:
# LinearRegression()

# %%
# now we can predict
ypred = model.predict(xtst)

# %%
# lets plot
sns.lineplot(x=xtst["tip"], y=ypred)
sns.scatterplot(x=xtst["tip"], y=ytst)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns_test_df = xtst
sns_test_df["y"] = ytst
sns_test_df
# Out:
#       tip      y
# 24   3.18  19.82
# 6    2.00   8.77
# 153  2.00  24.55
# 211  5.16  25.89
# 198  2.00  13.00
# 176  2.00  17.89
# 192  2.56  28.44
# 124  2.52  12.48
# 9    3.23  14.78
# 101  3.00  15.38
# 45   3.00  18.29
# 233  1.47  10.77
# 117  1.50  10.65
# 177  2.00  14.48
# 82   1.83  10.07
# 146  1.36  18.64
# 200  4.00  18.71
# 15   3.92  21.58
# 66   2.47  16.45
# 142  5.00  41.19
# 33   2.45  20.69
# 19   3.35  20.65
# 109  4.00  14.31
# 30   1.45   9.55
# 186  3.50  20.90
# 120  2.31  11.69
# 10   1.71  10.27
# 73   5.00  25.28
# 159  2.00  16.49
# 156  5.00  48.17
# 112  4.00  38.07
# 218  1.44   7.74
# 25   2.34  17.81
# 60   3.21  20.29
# 18   3.50  16.97
# 119  2.92  24.08
# 97   1.50  12.03
# 197  5.00  43.11
# 139  2.75  13.16
# 241  2.00  22.67
# 75   1.25  10.51
# 127  2.00  14.52
# 113  2.55  23.95
# 16   1.67  10.33
# 196  2.00  10.34
# 67   1.00   3.07
# 168  1.61  10.59
# 38   2.31  18.69
# 195  1.44   7.56

# %%
sns.lmplot(sns_test_df, x="tip", y="y", ci=99)
